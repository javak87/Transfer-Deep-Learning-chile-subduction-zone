# %%
import warnings
from EQTransformer.core.trainer import trainer
warnings.filterwarnings('ignore')

# %% [markdown]
# input_hdf5='/home/javak/.seisbench/datasets/iquique/waveforms.hdf5',
# input_csv='/home/javak/.seisbench/datasets/iquique/metadata.csv',

# %%
trainer(input_hdf5='/home/javak/Downloads/EQTransformer-master/ModelsAndSampleData/100samples.hdf5',
        input_csv='/home/javak/Downloads/EQTransformer-master/ModelsAndSampleData/100samples.csv',
        output_name='test_trainer',                
        cnn_blocks=2,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        add_event_r=0.6,
        add_gap_r=0.2,
        shift_event_r=0.9,
        add_noise_r=0.5, 
        mode='generator',
        train_valid_test_split=[0.60, 0.20, 0.20],
        batch_size=20,
        epochs=10, 
        patience=2,
        gpuid=None,
        gpu_limit=None)
# Out:
# Learning rate:  0.001
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# conv1d_133 (Conv1D)             (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_29 (MaxPooling1D) (None, 3000, 8)      0           conv1d_133[0][0]
# __________________________________________________________________________________________________
# conv1d_134 (Conv1D)             (None, 3000, 16)     1168        max_pooling1d_29[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from EQTransformer.core.tester import tester
tester(input_hdf5='/home/javak/Downloads/EQTransformer-master/ModelsAndSampleData/100samples.hdf5',
       input_testset='/home/javak/Downloads/EQTransformer-master/ModelsAndSampleData/test.npy',
       input_model='test_trainer_outputs/models/test_trainer_001.h5',
       output_name='test_tester',
       detection_threshold=0.20,                
       P_threshold=0.1,
       S_threshold=0.1, 
       number_of_plots=3,
       estimate_uncertainty=True, 
       number_of_sampling=2,
       input_dimention=(6000, 3),
       normalization_mode='std',
       mode='generator',
       batch_size=10,
       gpuid=None,
       gpu_limit=None)
# Out:
# Loading the model ...
# Loading is complete!
# Testing ...
# Writting results into: " test_tester_outputs "
#   0%|          | 0/12657 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /tmp/ipykernel_72239/2382989716.py in <module>
#      15        batch_size=10,
#      16        gpuid=None,
# ---> 17        gpu_limit=None)
#
# ~/miniconda3/envs/eqt/lib/python3.7/site-packages/EQTransformer/core/tester.py in tester(input_hdf5, input_testset, input_model, output_name, detection_threshold, P_threshold, S_threshold, number_of_plots, estimate_uncertainty, number_of_sampling, loss_weights, loss_types, input_dimention, normalization_mode, mode, batch_size, gpuid, gpu_limit)
#     332                 pred_SS = []
#     333                 for mc in range(args['number_of_sampling']):
# ...
