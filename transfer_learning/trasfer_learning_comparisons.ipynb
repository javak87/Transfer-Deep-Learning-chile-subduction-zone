# %%
import pickle
import os

# %%
with open(os.path.join('/home/javak/Sample_data_chile/Comparing PhaseNet and Catalog', "PhaseNet_result_p_picks.pkl"),'rb') as fp:
    PhaseNet_result_p_picks = pickle.load(fp)

with open(os.path.join('/home/javak/Sample_data_chile/Comparing PhaseNet and Catalog', "PhaseNet_result_s_picks.pkl"),'rb') as fs:
    PhaseNet_result_s_picks = pickle.load(fs)

with open(os.path.join('/home/javak/Sample_data_chile/Updated Catalog from Crist/catalog_2007_2021/manual picks', "day1.pkl"),'rb') as fn:
    manual_picks = pickle.load(fn)

# %%
manual_picks.head()
# Out:
#                     picks_time  picks_uncertainty network_code station_code  \
# 0  2012-06-30T00:09:26.048393Z                NaN           CX         PB01
# 1  2012-06-30T00:09:29.038393Z                NaN           CX         PB02
# 2  2012-06-30T00:09:27.798393Z                NaN           CX         PB03
# 3  2012-06-30T00:09:36.608391Z                NaN           CX         PB05
# 4  2012-06-30T00:09:30.298393Z                NaN           CX         PB06
#
#   phase_hint                 origins_time  origins_longitude  origins_latitude
# 0          P  2012-06-30T00:08:58.997298Z         -68.316424        -21.613279
# 1          P  2012-06-30T00:08:58.997298Z         -68.316424        -21.613279
# 2          P  2012-06-30T00:08:58.997298Z         -68.316424        -21.613279
# 3          P  2012-06-30T00:08:58.997298Z         -68.316424        -21.613279
# 4          P  2012-06-30T00:08:58.997298Z         -68.316424        -21.613279

# %%
PhaseNet_result_p_picks
# Out:
#               id                  timestamp      prob type
# 7971    CX.PB11. 2012-06-30 00:00:32.560000  0.454734    p
# 7972    CX.PB09. 2012-06-30 00:00:33.080000  0.481664    p
# 7973    CX.PB03. 2012-06-30 00:01:00.288393  0.489481    p
# 7979    CX.PB14. 2012-06-30 00:01:01.110000  0.388810    p
# 7980    CX.PB07. 2012-06-30 00:01:01.398393  0.330795    p
# ...          ...                        ...       ...  ...
# 20965   CX.PB10. 2012-06-30 23:59:47.880001  0.495551    p
# 20966   CX.PB06. 2012-06-30 23:59:49.878393  0.989441    p
# 20967   CX.PB11. 2012-06-30 23:59:51.130000  0.999736    p
# 20968  CX.MNMCX. 2012-06-30 23:59:59.219998  0.489426    p
# 20969   CX.PB12. 2012-06-30 23:59:59.930000  0.973031    p
#
# [12993 rows x 4 columns]
